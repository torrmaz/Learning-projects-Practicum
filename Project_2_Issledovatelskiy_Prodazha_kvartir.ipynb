# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Виктор, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-info">Привет Александр, на та так на ты)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Виктор, рад тебя видеть =)

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# Описание данных
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — общая площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd #Импортируем библиотеку

data=pd.read_csv('C:/Users/Владимир/Projects/real_estate_data.csv',sep=',') #Чтение файла csv с разделителем 
display(data.info())
display(data.describe())
display('Явных дубликатов обнаружено',data.duplicated().sum()) #кол-во явных дубликатов
display(data.head())
data.hist(bins=10,figsize=(15, 15))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            23699 non-null  int64
#  1   total_images          23699 non-null  int64
#  2   last_price            23699 non-null  float64
#  3   total_area            23699 non-null  float64
#  4   first_day_exposition  23699 non-null  object
#  5   rooms                 23699 non-null  int64
#  6   ceiling_height        14504 non-null  float64
#  7   floors_total          23613 non-null  float64
#  8   living_area           21796 non-null  float64
#  9   floor                 23699 non-null  int64
#  10  is_apartment          2775 non-null   object
#  11  studio                23699 non-null  bool
#  12  open_plan             23699 non-null  bool
#  13  kitchen_area          21421 non-null  float64
#  14  balcony               12180 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на явные дубликаты - основа предобработки данных

# %% [markdown]
# __Выводы__
#
# 1.__info()__
#
#     -неверные типы данных "is_apartment" должен содержать значения типа bool, а 'first_day_exposition' datetime
#
#     -нежелательное имя столбца cityCenters_nearest, не приведен к змеиному регистру
#
#     -большое колличество пропусков в датасете
#
# 2.__describe()__
#
#
#     -минимальное колличество rooms 0
#
#     -максимальная высота потолков в celling_height 100м
# 3.__head()__
#
#     -Время в first_day_exposition округлено до дней
#
#     -пропуски в данных наблюдаются с первой строки
#
# Вывод:Судя по всему перед исследованием следует провести большую работу с пропущенными значениями

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть, план намечен.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработаем столбец is_apartment

# %%
display(data['is_apartment'].isna().sum())
data['is_apartment'] = data['is_apartment'].fillna(False).astype('bool')
data['is_apartment'].value_counts()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верно. Это булевый столбец

# %% [markdown]
# Меняем тип на bool опираясь на описание данных,заодно заменяем все пропуски столбца значением False удобства последующего анализа.

# %% [markdown]
# #### Рассмотрим столбцы  cityCenters_nearest    parks_around3000   ponds_around3000

# %%
data=data.rename(columns={'cityCenters_nearest':'city_centers_nearest','parks_around3000':'parks_around', 'ponds_around3000':'ponds_around'})# переименование столбцов
data.columns

# %% [markdown]
#  Переименовываем столбцы в соответствии со змеиным регистром

# %% [markdown]
# #### Приведем столбец  first_day_exposition к формату datetime64

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data.dtypes

# %% [markdown]
# #### Столбец locality_name
# Избавляемся от неявных дубликатов заменяя 'ё' на 'е',а 'городской поселок' на 'поселок городского типа'
# Заодно проверяем на явные дубликаты

# %%
display('Уникальных названий', data['locality_name'].nunique())
display(data['locality_name'].isna().sum())#49 пропусков в названии населенных пунктов
data = data.dropna(subset=['locality_name']) #удаление пропусков
display(data['locality_name'].unique())#уникальные значения'locality_name'
data['locality_name'] = data['locality_name'].str.lower()
data['locality_name'] =(
    data['locality_name']
    .str.replace('ё', 'е')
    .str.replace('городской поселок', 'поселок городского типа', regex=True)
)
display('Уникальных названий', data['locality_name'].nunique())
display('Колличествово явных дубликатов',data.duplicated().sum()) #кол-во явных дубликатов

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно например вот так:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
#
# </div>

# %% [markdown]
# #### Изучим столбец ceiling_height

# %%
display('#колличество пропусков',data.ceiling_height.isna().sum()) #колличество пропусков 9195
display(data['ceiling_height'].describe()) #краткая информация по столбцу "ceiling_height"
data.loc[data['ceiling_height'] > 10, 'ceiling_height']=\
data.query('ceiling_height>10')['ceiling_height']/10#Все значения больше 10 делим на 10 и возвращаем на свои места
ceil_median=data.query('ceiling_height > 2 and ceiling_height < 6')['ceiling_height'].median()# считаем медиану между
data.loc[(data['ceiling_height'] < 2)&(data['ceiling_height'] > 10), 'ceiling_height'] = ceil_median
data['ceiling_height'] = data['ceiling_height'].fillna(ceil_median)#замена пропусков медианным значением
display('колличество квартир с потолками равными')
display(data['ceiling_height'].value_counts()) 
data['ceiling_height'].sort_values().plot(
    y='ceiling_height', 
    kind='hist', 
    bins=10, 
    range=(2,6),
    grid=True);
display(data['ceiling_height'].unique())

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Молодец, что не хардкодишь. А используешь условие

# %% [markdown]
# Возможно при заполнении столбца произошла опечатка и такие значения как 2.5 м записалось как 25м.Разделили слишком высокие потолки на 10.Осуществили замену пропущенных значений на медианные, медианное значение берем без учета слишком низких и высоких потолков.

# %% [markdown]
# #### Столбец balcony

# %%
display(data['balcony'].isna().sum())#выводим колличество пропусков в каждом столбце
data['balcony']=data['balcony'].fillna(value='0')#значения NaN ['balcony'] заиеняем на 0
data['balcony']=data['balcony'].astype('int')# меняем тип столбца на int
data.balcony.isna().sum()#прверка на наличие пропусков

# %% [markdown]
# Полагаем что отсутствие информации о балконе в столбце, указывает на его отсутствие в квартире, заменяем отсутствующие значения на ноль.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# #### Столбец floors_total

# %%
display(data.loc[data['floors_total'].isna()].head(10))
data['floors_total'].isna().sum()

# %% [markdown]
# Найдено 85 пропущенных значений, и так как из остальных столбцов невозможно выявить этажность дома, оставляем данный столбец не тронутым

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Если пропусков меньше 5-10% их можно удалить. Т.к. их мало и на данные это не повлияет

# %% [markdown]
# #### Столбец living_area

# %%
display(data['living_area'].describe())
data.loc[data['living_area']<6,'living_area']=None# их заменим на None
display(data['living_area'].isna().sum())#строки с отсутствующими значениями не на что заменить оставим их для последующего анализа 
display(data.groupby('living_area')['last_price'].describe())
display(len(data.query('6>living_area>78')))
data.boxplot('living_area', figsize=(10,12), grid=True)
display(data['living_area'].describe())

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: Рекомендую не смотреть данные "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их (если они соответствуют здравому смыслу). В этом поможет метод boxplot()
# </div>
# <div class="alert alert-info">Хорошо, если я на этом этапе использую boxplot то придется выкинуть 1904 строки, как я понял нужно было заниаться аномалиями на этапе предобработки, что бы не фильтровать во время исследовательского анализа
#
# Или же нет. Нужно создать чистый датасет в одну строку фильтруя по какому то одному признаку, и исследовательский анализ проводить с ним? Не могу предположить по какому.
#
# Короче два стула_ или данных мало останется (но они будут чистейшими),или почти не тронутый датасет но с вбросами.
#
# Поэтому и фильтрую в конце
#
# Напиши, первая моя мысль правильная?</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
# не совсем. Боксплот не идеален (он лишь показывает математическое распределение данных). Но дальше ты уже сам решает - является ли это выборосом или нет

# %% [markdown]
# В России, согласно законодательству, минимальная жилая площадь для одного человека составляет не менее 6-8 квадратных метров.Заменим отсутствующие значения на None

# %% [markdown]
# #### kitchen_area

# %%
display(data['kitchen_area'].isna().sum())#2269 пропущенных значения
data['kitchen_area']=data['kitchen_area'].dropna()#удаляю строки с пропусками
display(data['kitchen_area'].isna().sum())

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Замена пропущенных значений на медиану может исказить данные и внести некоторую проблему при дальнейшем анализе. Позволь мне рассказать подробнее о причинах и последствиях такого подхода.
#
# 1. Искажение распределения: Когда мы заменяем пропущенные значения на медиану, мы фактически добавляем новые значения в набор данных. Это может привести к смещению распределения и искажению статистических свойств данных. Замена на медиану может привести к тому, что данные будут выглядеть более однородными, чем они есть на самом деле.
#
# 2. Возможные последствия: Замена пропущенных значений на медиану может повлиять на многие аспекты анализа данных:
#
#    - Статистические тесты: Искаженные данные могут привести к неправильным выводам в статистических тестах. Использование искаженных данных может привести к неверным результатам тестов на значимость и оценке эффектов между группами или условиями.
#
#    - Моделирование: В случае использования искаженных данных для построения моделей, модели также могут страдать от искажения и давать неправильные предсказания или выводы. Это может быть особенно важно, если пропущенные значения связаны с ключевыми переменными модели.
#
#    - Выводы и интерпретация: Искаженные данные могут привести к неверным выводам и неправильной интерпретации результатов. Например, если пропущенные значения связаны с важными факторами, замена на медиану может привести к неправильному пониманию влияния этих факторов на исследуемую переменную.
#
# Итак, вместо замены пропущенных значений на медиану, рекомендуется применять другие подходы к обработке пропущенных данных, такие как:
#
# - Удаление записей с пропущенными значениями: Если количество записей с пропущенными значениями невелико по сравнению с общим объемом данных, удаление этих записей может быть разумным подходом.
#
# - Импутация данных: Использование более сложных методов, таких как импутация данных, может помочь восстановить пропущенные значения на основе других переменных в наборе данных. Например, можно использовать модели машинного обучения, чтобы предсказать пропущенные значения на основе имеющихся данных.
#
# Важно оценивать причину появления пропущенных значений и выбирать подход к их обработке на основе специфики данных и целей исследования. Правильная обработка пропущенных значений помогает сохранить точность и надежность анализа данных.

# %% [markdown]
# <div class="alert alert-info">Выбираю простой путь удаления. Скажи допустима ли замена на медиану в столбце ceiling_height там пропусков в 5 раз больше,следовательно и искажение будеть большое..удалить ведь тоже нельзя</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Верно, лучше оставить

# %% [markdown]
# Удаляем пропущенные значения в столбце kitchen area

# %% [markdown]
# #### airports_nearest

# %%
display(data.airports_nearest.isna().sum())#5534 пропусков(оставляем так как по смежным данным таблицы эти пропуски не заполнить)
display(data['airports_nearest'].min()) #самое маленькое значение здесь неправдоподобно
data.loc[data['airports_nearest']==0,'airports_nearest']=None
data['airports_nearest'].describe()

# %% [markdown]
# Из таблицы describe выявляем что минимальное значение расстояния до аэрапорта 0, маловероятно что квартиру сдают в аэропорту, скорее всего это ошибка при заполнении, человеческий фактор

# %% [markdown]
# #### Столбец parks_around

# %%
display(data['parks_around'].unique())#значения NaN здесь скорее всего означают что парков в пределах 3 км нет
data['parks_around'] = data['parks_around'].fillna(0).astype('int')#их заменяем на нули, меняем тип данных т.к. значения у всех целые
display(data['parks_around'].isna().sum())#5518 пропусков NaN
data.query('parks_around ==0').count()#15590 нулевых начений

# %% [markdown]
# Эти данные собирались в автоматическом режиме, продолжим искать причину большого числа пропусков

# %% [markdown]
# #### Попробуем исследовать похожий столбец parks_nearest

# %%
display(data['parks_nearest'].agg(['min','max','mean','median']))#макимальное значение выбивается из ограниченя 3000м.
display(data['parks_nearest'].isna().sum())#15586 пропусков
display(data.query('parks_nearest > 3000')['parks_nearest'])

# %% [markdown]
# Сверим данные этих столбцов,в parks_nearest 15586 пропущенных значения + 4 значения свыше расстояния в 3000м это означает, что у такого же колличества строк parks_around будет значение 0. Здесь с данными все в порядке.

# %% [markdown]
# #### Столбец ponds_around

# %%
display(data['ponds_around'].agg(['min','max','median']))
display(data['ponds_around'].isna().sum())#5510 пропусков
data['ponds_around'] = data['ponds_around'].fillna(0).astype('int')#заменяим их значением 0, по аналогии с предыдущим столбцом
data.query('ponds_around >0').count()#14565 нулевых начений

# %% [markdown]
# #### Столбец ponds_nearest

# %%
display(data['ponds_nearest'].agg(['min','max','median']))
display(data['ponds_nearest'].isna().sum())

# %% [markdown]
# По аналогии с парками с водоемами все в порядке.Не требуется дополнительной обработки.На 14565 нулевых значения ponds_nearest, 14565 пропущенных значения ponds_around.

# %% [markdown]
# #### Столбец days_exposition

# %%
display(data['days_exposition'].agg(['min','max','median']))
display(data['days_exposition'].isna().sum())#3180 пропусков

# %% [markdown]
# В этом столбце пропущенные значения означают что объявления все еще не сняти и до сих пор актуальны, оставяем все пропуски.

# %% [markdown]
# Вывод:По результату проведённой предобработки данных, можно сказать что довольно большая часть данных влияющая на решение о прибретении квартир, потеряна при выгрузке таблицы либо отсутствует.Отсутствие данных в столбцах ceiling_height и living_area может повлиять на итоговое исследование.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует вывод после раздела (можно описать качество исходных данных). Поправишь, этот момент в проекте?
# </div>
# <div class="alert alert-info">Готово</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# #### Добавление цены одного квадратного метра

# %%
data['meter_price']=data['last_price']/data['total_area']#делим цену на метраж
data['meter_price']=data['meter_price'].round(2)#Отбрасываем до двух знаков после запятой
data.head()

# %% [markdown]
# #### Добавление столбцов дня недели, месяца и года публикации объявления

# %%
data['week_day_exposition']=data['first_day_exposition'].dt.weekday
data['month_exposition']=data['first_day_exposition'].astype('datetime64[M]')
data['year_exposition']=data['first_day_exposition'].dt.year
data.head()
data.value_counts('month_exposition')#

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://runebook.dev/ru/docs/numpy/reference/arrays.datetime
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
# </div>

# %% [markdown]
# <div class="alert alert-info">Ага, попробовал.график по месяцам стал информативнее, ссылочки забрал,</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %% [markdown]
# Видим что колличество объявлений растет вплоть до 2018 года, в 2019 году происходит спад, возможно год еще не закончился на момент создания датасета.Самый большой рост числа объявлений произошел в 2017 году, почти в три раза.

# %% [markdown]
# #### Добавление типа этажа квартиры

# %%
def floor (row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
data['floor_type'] = data.apply(floor, axis=1)#применение функции ко всем строкам 
data.value_counts('floor_type')

# %% [markdown]
# #### Добавление расстояния до центра города в километрах

# %%
data['city_сenters_nearest_km']=(data['city_centers_nearest']/1000).round()
data.head()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров.

# %% [markdown]
# ##### Рассмотрим общую площадь

# %%
from matplotlib import pyplot as plt 
display(data['total_area'].describe())
print('Диаграмма размаха площади квартиры')
data.boxplot('total_area', figsize=(10,12), grid=True)
data.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,500))
data_area=data.query('total_area<112')
data_area.plot(kind='hist', y='total_area',title='Распределение предложений квартир по площади',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Площадь квартиры в кв.м.')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что используешь метод range() для определения пиковых значений
# </div>

# %% [markdown]
# Данные на графике распределены нормально, судя по диаграмме размаха имеется большое коллличество вбросов расчитываем границу верхнего уса как 69+1.5*29=112.5 это граница после которой начинаются вбросы, проведем анализ без них.
#
# Вывод Нормальное распределение со смещением на большое колличество предложений маленьких квартир от 35 до 50 кв.м.

# %% [markdown]
# ##### Рассмотрим цены за квартиры

# %%
display(data['last_price'].describe())
display(data['last_price'].min())
print('Диаграмма размаха площади квартиры')
data.boxplot('last_price',figsize=(10,20),grid=True)
data.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,50000000))
data_price=data.query('last_price<12000000')
data_price.plot(kind='hist', y='last_price',title='Распределение цен на квартиры',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Цена')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Не подходят для анализа квартиры дороже 12 млн. Распределение выглядит нормальным за исключением некоторых пиков

# %% [markdown]
# ##### площадь кухни

# %%
display(data['kitchen_area'].describe())
print('Диаграмма размаха площади кухни')
data.boxplot('kitchen_area', figsize=(10,12), grid=True)
data_k_area=data.query('kitchen_area<19')
data_k_area.plot(kind='hist', y='kitchen_area',title='Распределение площадей кухни',bins=20, figsize=(15,5), grid=True)
plt.xlabel('Площадь кухни в кв.м.')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Не подходят для анализа площади кухни меньше 19 кв. м. Самая популярная площадь кухни 9-10 кв.м.

# %% [markdown]
# ##### Жилая площадь

# %%
display(data['living_area'].describe())
print('Диаграмма размаха жилой площади')
data.boxplot('living_area', figsize=(10,12), grid=True)
data.plot(y = 'living_area', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,100))
data_livarea=data.query('living_area<78')
data_livarea.plot(kind='hist', y='living_area',title='Распределение площадей',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Площадь жилой площади в кв.м.')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Отбрасываем все площади выше 78 кв.м. На графике видна высокая популярность у помещений с малой жилой площадью

# %% [markdown]
# ##### Количество комнат

# %%
display(data['rooms'].describe())
print('Диаграмма размаха комнат')
data.boxplot('rooms', figsize=(10,12), grid=True)
data_rooms=data.query('rooms<5')
data_rooms.plot(y = 'rooms', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,5))

# %% [markdown]
# Мало предложений на квартиры с колличеством комнат больше трех, так же на графике видно что предложений "однушек" и "двушек" примерно одинаково.

# %% [markdown]
# ##### Высота потолков

# %%
display(data['ceiling_height'].describe())
print('Диаграмма размаха высоты потолков')
data.boxplot('ceiling_height', figsize=(10,12), grid=True)
data.plot(y = 'ceiling_height', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (2,4))
data_ceiling_height=data.query('2.5<ceiling_height<3.1')
data_ceiling_height.plot(kind='hist', y='ceiling_height',title='Распределение площадей',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Распределение высоты потолка в кв.м.')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Средняя высота потолка для представленных квартир 2.7 метров, в данных наблюдалось большое число аномалий,что возможно исказило анализ, подозрительно что мало квартир сдается с трехметровыми потолками.

# %% [markdown]
# ##### Тип этажа квартиры

# %%
data_type=data.groupby(['floor_type']).agg({'last_price':'count'})
data_type.plot.bar(y = 'last_price', grid=True, figsize = (10,5))
data_type

# %% [markdown]
# Совершенно логичное распределение квартир.квартиры на смежных этажах сдаются в три раза чаще чем на крайних.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %% [markdown]
# ##### общее количество этажей в доме

# %%
display(data['floors_total'].describe())
print('Диаграмма размаха для высоты дома')
data.boxplot('floors_total', figsize=(10,12), grid=True)
data.plot(y = 'floors_total', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,80))
data_area=data.query('floors_total<28')
data_area.plot(kind='hist', y='floors_total',title='Распределение этажности здания',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Высота дома в этажах')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Большое число объявлений для типовых строений 5 и 9 этажей

# %% [markdown]
# ##### Расстояние до центра города в метрах;

# %%
display(data['city_centers_nearest'].describe())
print('Диаграмма размаха для расстояния до ближайшего центра города')
data.boxplot('city_centers_nearest', figsize=(10,12), grid=True)
data.plot(y = 'city_centers_nearest', kind = 'hist', bins = 100, grid=True, figsize = (10,5))
data_area=data.query('city_centers_nearest<27000')
data_area.plot(kind='hist', y='city_centers_nearest',title='Распределение расстояния до центра',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Расстояние до центра в м.')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Большая часть квартир распологается не дальше чем 15 км от центра города. Так же наблюдается пик популярности у квартир в пределах 5 км.

# %% [markdown]
# ##### Расстояние до ближайшего парка

# %%
display(data['parks_nearest'].describe())
print('Диаграмма размаха для расстояния до ближайшего парка')
data.boxplot('parks_nearest', figsize=(10,12), grid=True)
data.plot(y = 'parks_nearest', kind = 'hist', bins = 100, grid=True, figsize = (10,5))
data_area=data.query('parks_nearest<1098')
data_area.plot(kind='hist', y='parks_nearest',title='Распределение расстояния до парка',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Расстояние до парка м.')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Вывод: если парк находится поблизости то он в пределах одного километра от квартиры, редко встечаются парки что находятся дальше

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Всё верно

# %% [markdown]
# #### Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.

# %%
display(data['days_exposition'].describe())
print('Диаграмма размаха для колличества дней со дня выставления объявления')
data.boxplot('days_exposition', figsize=(10,12), grid=True)
data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid=True, figsize = (10,5))
data_area=data.query('days_exposition<510')
data_area.plot(kind='hist', y='days_exposition',title='Распределение скорости сдачи объявления',bins=100, figsize=(15,5), grid=True)
plt.xlabel('Дней с начала размещения объявления')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Вывод: быстрыми продажами можно назвать те что закрывались за первые 45 дней, а медленными те что здаются более 231 дня.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы рекомендавал брать 25% и 75% распределение данных за быстрые и долгие сооветственно
# </div>
# <div class="alert alert-info">Не додумался</div>

# %% [markdown]
# #### Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %% [markdown]
# ##### Зависит ли цена от  колличества комнат, общей площади и расстояния до центра

# %%
(data_rooms
     .groupby(['rooms']).agg({'last_price':'median'})
     .plot(y = 'last_price', grid=True, figsize = (10,5),kind='bar')
)
data['rooms'].corr(data['last_price'])#Коэффициент пирсона

# %% [markdown]
# Коэффициент пирсона >0 Следовательно с ростом числа комнат растет и цена на квартиру.

# %%
(data
     .query('last_price<12000000 and total_area<112')
     .pivot_table(index='last_price', values=['total_area'])
     .plot(style='o',grid=True, figsize=(12, 5),alpha=0.5, title='График зависимости цены от площади')
)
plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel(' Площадь')
plt.show()
print('Коэффициент Пирсона для общей площади')
display(data['total_area'].corr(data['last_price']))#Коэффициент пирсона

# %% [markdown]
# Здесь корреляция от еще сильнее, с увеличением площади продаваемой квартиры растет и цена

# %%
(data
     .query('last_price<12000000 and living_area<112')
     .pivot_table(index='last_price', values=['living_area'])
     .plot(style='o',grid=True, figsize=(12, 5),alpha=0.5, title='График зависимости цены от жилой площади')
)
plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Жилая лощадь')
plt.show()
print('Коэффициент Пирсона для жилой площади')
display(data['living_area'].corr(data['last_price']))#Коэффициент пирсона

# %% [markdown]
# Жилая площадь квартир имеет меньшее влияние на ценообразование нежели общая площадь квартиры.

# %%
(data
     .query('last_price<12000000 and kitchen_area<112')
     .pivot_table(index='last_price', values=['kitchen_area'])
     .plot(style='o',grid=True, figsize=(12, 5),alpha=0.5, title='График зависимости цены от площади кухни')
)
plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Площадь кухни')
plt.show()
print('Коэффициент Пирсона для  площади кухни')
display(data['kitchen_area'].corr(data['last_price']))#Коэффициент пирсона

# %% [markdown]
# Из всех показателей площади, площадь кухни имеет самое наименьшее влияние на цену квартиры, это означает что при формировании цены оценивается общая площадь квартиры, а жилая площадь и площадь кухни хоть и влияют на цену но опосредованно так как в больших квартирах скорее всего будет большая кухня и большие комнаты

# %%
(data
     .query('last_price<12000000 and city_сenters_nearest_km<27')
     .pivot_table(index='last_price', values=['city_сenters_nearest_km'])
     .plot(style='o',grid=True, figsize=(12, 5),alpha=0.5, title='График зависимости цены от удалённости от центра')
)
plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Удалённость от центра')
plt.show()
data['city_сenters_nearest_km'].corr(data['last_price'])#Коэффициент пирсона

# %% [markdown]
# По мере удаления от центра цена падает что подтверждает отрицательный коэффициент Пирсона

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Нужно создать датафрейм без выбросов и работать именно с ним. Твой способ с фильтрацией выбросов в каждом конкретном случае не самый оптимальный.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# График сильно перегружен. Чем проще - тем лучше. Один график = одна мысль

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Давай графики зависимостей подкрепим корреляцией Пирсона и сразу интерпретировать полученные данные в разделе?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Нет решения по площади кухни и жилой площади. Добавь, пожалуйста

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Зависимости прерывных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (сгруппировав предварительно)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Смотри: нам нужно рассмотреть зависимости всех площадей от итоговой цены (а ты выше смотришь только от общей площади)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №3__
#
# При составлении графиков, лучше не срезать данные, а строить по всем данным

# %% [markdown]
# ##### Зависит ли цена от типа этажа квартиры

# %%
(data
     .query('last_price<12000000')
     .pivot_table(index='floor_type', values='last_price').sort_values(by='last_price', ascending=True)
     .plot(grid=True, figsize=(9, 5),linewidth=3, title='Зависимость цены от этажа расположения квартиры')
)
plt.xlabel('Этаж расположения квартиры')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Вывод: Квартиры на первом этаже самые бюджетные, а квартиры с этажом типа "другой" составляют верхний ценовой сегмент.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %% [markdown]
# #### даты размещения (день недели, месяц, год).

# %%
(data
    
     .pivot_table(index='week_day_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от даты размещения')
)
plt.xlabel('День недели размещения')
plt.ylabel('Цена')
plt.show()

# %%
(data
    
     .pivot_table(index='month_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от месяца размещения')
)
plt.xlabel('Месяц размещения')
plt.ylabel('Цена')
plt.show()

# %%
(data
     .query('last_price<12000000')
     .pivot_table(index='year_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от года размещения')
)
plt.xlabel('Год размещения')
plt.ylabel('Цена')
plt.show()
(data
     .query('total_area<12000')
     .pivot_table(index='year_exposition', values=['total_area'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от площади квартиры')
)
plt.xlabel('Год размещения')
plt.ylabel('Площадь')
plt.show()

# %% [markdown]
# Вывод: Нет корреляции цены от месяца и дня недели. Видно что с 2014 по 2018 год площадь проданных квартир уменьшается, тренд цены так же падает скорее всего из за уменьшения площади продаванемых квартир. Отрезок с 2016 по 2018 интересен тем что при уменьшении площади продаваемыы квартир цена на них остается той же.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим динамику цены и площади продаваемых квартир. И потом пересмотрим выводы, т.к., возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличный инсайд для заказика. Молодец)

# %% [markdown]
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %%
data_10_top = data.pivot_table(index='locality_name', values=['first_day_exposition'], aggfunc='count').sort_values(by='first_day_exposition', ascending=False).head(10)
data_10_top.columns=['flat_number']
data_10_top['cost_per_meter_mean'] = data.pivot_table(index='locality_name', values='meter_price', aggfunc='mean')
data_10_top=data_10_top.style.format({'cost_per_meter_mean':'{:.2f} Р'})
data_10_top

# %% [markdown]
# средняя цена одного квадратного метра санкт-петербурге на отметке 115 тыс.р за ним идут населенные пункты пушкин (103тыс.р.) и поселок парголово (90тыс.р.)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Смотри, как можно в 1 строку:

# %%
data.groupby('locality_name').agg({'balcony':'count', 'last_price':'median'}) \
    .sort_values(by = 'balcony', ascending = False) \
    .head(10)

# %% [markdown]
# #### Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра

# %%
peter_flat= data.loc[data['locality_name'] == 'санкт-петербург'].sort_values(by='city_сenters_nearest_km')
(peter_flat
     .pivot_table(index='city_сenters_nearest_km', values=['last_price'],aggfunc='mean')
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены расстояния до центра питера')
)

# %% [markdown]
# Цена снижается при удалении от центра, после уверенного снижения цены в промежутке с 3 до 6 км. наблюдается небольшой рост, а затем плавный спад.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# По итог проделанной работы по подготовке данных к анализу мы столкнулись с большим количеством пропусков в колонках, которые могут влиять как на среднюю цену предлодения квартир на рынке. Тем не менее какие-то данные мы заполнили медианным значением дабы не терять основной массив статистичесих данных, а некоторые данные оставили без изменений с пропущенными значениями. Ошибок связанных с человеческим фактором немного.
#
# После избавления от 'мусорных' и выбивающихся значений мы выполнили такие операции как подсчёт средней стоимости квадратного метра жилья, стоимость каждого километра удаления от центра, выделили сегмент квартир расположенных в центре и проанализировали их параметры, а так же вывели статистику по скорости продажи объявления с даты его размещения, факторы влияющие на это и проанализировали статистику продаж в зависимости от периода размещения объявления.
#
# Для большей наглядности при анализе использовались графики, из которых лего можно сделать вывод о том, что лидером по размещению объявлений о продаже недвижимости является "Санкт-Петербург", несмотря на это средняя цена квадратного метра не сильно тличается от области. Тенденция рынка такова, что начиная с 2019 года активно растёт цена и спрос на квартиры в Петербурге.
#
# В основном влияют на итоговую стоимость квартиры такие показатели как
#
# В сухом остатке в большинстве случаев покупки жилья люди выбирают 1-2 комнатные квартиры в высотной новостройке по периметру города Санкт-Петребург, с средней стоимостью в 100 т.р. за кв.метр. и высотой потолков 2,75. Таким образом можно сделать вывод о том, что количество таких домов и соответственно предложений будет расти в след за ценой в отличии от цен на жильё расположенного по центру исторического района города в невысоких домах из старого фонда.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Замена пропусков
#
# 2) Построить графики зависимостей
#
# 3) Корреляция Пирсона для площадей
#
# 4) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 5) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №2 </b>
#
#
#
# Отличная работа, осталось поправить один момент:
#
# ---
#
# Нужно поправить:
#
#
# 1) Построить графики зависимостей (жилая, кухня)
#
# 2) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №3__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.
